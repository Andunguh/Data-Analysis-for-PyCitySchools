# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd

# File to Load (Remember to Change These)
school_data_to_load = "Resources/schools_complete.csv"
student_data_to_load = "Resources/students_complete.csv"

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %%
school_data
# Out:
#     School ID            school_name      type  size   budget
# 0           0      Huang High School  District  2917  1910635
# 1           1   Figueroa High School  District  2949  1884411
# 2           2    Shelton High School   Charter  1761  1056600
# 3           3  Hernandez High School  District  4635  3022020
# 4           4    Griffin High School   Charter  1468   917500
# 5           5     Wilson High School   Charter  2283  1319574
# 6           6    Cabrera High School   Charter  1858  1081356
# 7           7     Bailey High School  District  4976  3124928
# 8           8     Holden High School   Charter   427   248087
# 9           9       Pena High School   Charter   962   585858
# 10         10     Wright High School   Charter  1800  1049400
# 11         11  Rodriguez High School  District  3999  2547363
# 12         12    Johnson High School  District  4761  3094650
# 13         13       Ford High School  District  2739  1763916
# ...

# %%
student_data
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score
# 0                 66          79
# 1                 94          61
# ...

# %%
school_data_complete
# Out:
#        Student ID       student_name gender grade         school_name  \
# 0               0       Paul Bradley      M   9th   Huang High School
# 1               1       Victor Smith      M  12th   Huang High School
# 2               2    Kevin Rodriguez      M  12th   Huang High School
# 3               3  Dr. Richard Scott      M  12th   Huang High School
# 4               4         Bonnie Ray      F   9th   Huang High School
# ...           ...                ...    ...   ...                 ...
# 39165       39165       Donna Howard      F  12th  Thomas High School
# 39166       39166          Dawn Bell      F  10th  Thomas High School
# 39167       39167     Rebecca Tanner      F   9th  Thomas High School
# 39168       39168       Desiree Kidd      F  10th  Thomas High School
# 39169       39169    Carolyn Jackson      F  11th  Thomas High School
#
#        reading_score  math_score  School ID      type  size   budget
# ...

# %% [markdown]
# ## District Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average math score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing math score (70 or greater)
#
# * Calculate the percentage of students with a passing reading score (70 or greater)
#
# * Calculate the percentage of students who passed math **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
number_schools=len(list(set(school_data_complete["school_name"].values)))

number_students=len(list((school_data_complete["student_name"].values)))

# %%
district_summary_df=pd.DataFrame({
    "Total Schools":[number_schools],
    "Total_Students":[number_students]
})
district_summary_df
# Out:
#    Total Schools  Total_Students
# 0             15           39170

# %%
school_data_complete.describe()
# Out:
#          Student ID  reading_score    math_score     School ID          size  \
# count  39170.000000    39170.00000  39170.000000  39170.000000  39170.000000
# mean   19584.500000       81.87784     78.985371      6.978172   3332.957110
# std    11307.549359       10.23958     12.309968      4.444329   1323.914069
# min        0.000000       63.00000     55.000000      0.000000    427.000000
# 25%     9792.250000       73.00000     69.000000      3.000000   1858.000000
# 50%    19584.500000       82.00000     79.000000      7.000000   2949.000000
# 75%    29376.750000       91.00000     89.000000     11.000000   4635.000000
# max    39169.000000       99.00000     99.000000     14.000000   4976.000000
#
#              budget
# count  3.917000e+04
# mean   2.117241e+06
# std    8.749987e+05
# min    2.480870e+05
# 25%    1.081356e+06
# 50%    1.910635e+06
# 75%    3.022020e+06
# max    3.124928e+06

# %%
total_budget=pd.pivot_table(school_data_complete,values= "budget",index="school_name",aggfunc="max")
total_budget
# Out:
#                         budget
# school_name
# Bailey High School     3124928
# Cabrera High School    1081356
# Figueroa High School   1884411
# Ford High School       1763916
# Griffin High School     917500
# Hernandez High School  3022020
# Holden High School      248087
# Huang High School      1910635
# Johnson High School    3094650
# Pena High School        585858
# Rodriguez High School  2547363
# Shelton High School    1056600
# Thomas High School     1043130
# Wilson High School     1319574
# Wright High School     1049400

# %%
budget_sum=total_budget.budget.sum()
budget_sum
# Out:
# 24649428

# %%
district_summary_df=pd.DataFrame({
    "Total Schools":[number_schools],
    "Total_Students":[number_students],
    "Total_Budget":[budget_sum]
})
district_summary_df
# Out:
#    Total Schools  Total_Students  Total_Budget
# 0             15           39170      24649428

# %%
math_score=pd.pivot_table(school_data_complete,values= "math_score",index="school_name",aggfunc="sum")
math_score
# Out:
#                        math_score
# school_name
# Bailey High School         383393
# Cabrera High School        154329
# Figueroa High School       226223
# Ford High School           211184
# Griffin High School        122360
# Hernandez High School      358238
# Holden High School          35784
# Huang High School          223528
# Johnson High School        366942
# Pena High School            80654
# Rodriguez High School      307294
# Shelton High School        146796
# Thomas High School         136389
# Wilson High School         190115
# Wright High School         150628

# %%
average_math_score=school_data_complete["math_score"].mean()
average_math_score
# Out:
# 78.98537145774827

# %%
average_reading_score=school_data_complete["reading_score"].mean()
average_reading_score
# Out:
# 81.87784018381414

# %%
district_summary_df=pd.DataFrame({
    "Total Schools":[number_schools],
    "Total_Students":[number_students],
    "Total_Budget":[budget_sum],
    "average_math_score":average_math_score,
    "average_reading_score":average_reading_score,
    
})
district_summary_df
# Out:
#    Total Schools  Total_Students  Total_Budget  average_math_score  \
# 0             15           39170      24649428           78.985371
#
#    average_reading_score
# 0               81.87784

# %%
math_passing=school_data_complete[school_data_complete["math_score"]>=70].count()["student_name"]
math_passing
# Out:
# 29370

# %%
reading_passing=school_data_complete[school_data_complete["reading_score"]>=70].count()["student_name"]
reading_passing
# Out:
# 33610

# %%
district_summary_df=pd.DataFrame({
    "Total Schools":[number_schools],
    "Total_Students":[number_students],
    "Total_Budget":[budget_sum],
     "average_math_score":average_math_score,
    "average_reading_score":average_reading_score,
    "Math_passing":[100*math_passing/number_students],
    "reading_passing":[100*reading_passing/number_students]
    
})
district_summary_df
# Out:
#    Total Schools  Total_Students  Total_Budget  average_math_score  \
# 0             15           39170      24649428           78.985371
#
#    average_reading_score  Math_passing  reading_passing
# 0               81.87784     74.980853        85.805463

# %%
overall_passing=school_data_complete[(school_data_complete["math_score"]>=70) & (school_data_complete["reading_score"]>=70)].count()["student_name"]
overall_passing
# Out:
# 25528

# %%
district_summary_df=pd.DataFrame({
    "Total Schools":[number_schools],
    "Total_Students":[number_students],
    "Total_Budget":[budget_sum],
     "average_math_score":average_math_score,
    "average_reading_score":average_reading_score,
    "Math_passing":[100*math_passing/number_students],
    "reading_passing":[100*reading_passing/number_students],
    "overall_passing":[100*overall_passing/number_students]
    
})
district_summary_df
# Out:
#    Total Schools  Total_Students  Total_Budget  average_math_score  \
# 0             15           39170      24649428           78.985371
#
#    average_reading_score  Math_passing  reading_passing  overall_passing
# 0               81.87784     74.980853        85.805463        65.172326

# %% [markdown]
# * Create an overview table that summarizes key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed math **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635

# %%
school_data_complete["math_passing"]=school_data_complete.math_score>=70
school_data_complete["reading_passing"]=school_data_complete.reading_score>=70
school_data_complete["overall_passing"]=school_data_complete.math_score>=70 
school_data_complete["overall_passing"]&=school_data_complete.reading_score>=70

# %%
school_data_complete['number_students']=school_data_complete['student_name']

# %%
school_data_complete.head()
# Out:
#    Student ID       student_name gender grade        school_name  \
# 0           0       Paul Bradley      M   9th  Huang High School
# 1           1       Victor Smith      M  12th  Huang High School
# 2           2    Kevin Rodriguez      M  12th  Huang High School
# 3           3  Dr. Richard Scott      M  12th  Huang High School
# 4           4         Bonnie Ray      F   9th  Huang High School
#
#    reading_score  math_score  School ID      type  size   budget  \
# 0             66          79          0  District  2917  1910635
# 1             94          61          0  District  2917  1910635
# 2             90          60          0  District  2917  1910635
# 3             67          58          0  District  2917  1910635
# 4             97          84          0  District  2917  1910635
#
#    math_passing  reading_passing  overall_passing  budget2    number_students
# 0          True            False            False  1910635       Paul Bradley
# ...

# %%
T1=pd.pivot_table(school_data_complete,index=["school_name","type"],values=["number_students","budget","math_score","reading_score","math_passing","reading_passing","overall_passing"],aggfunc={'number_students': 'count','budget': 'max','math_score':'mean','reading_score':'mean','math_passing':'mean','reading_passing':'mean','overall_passing':'mean'})
T1
# Out:
#                                  budget  math_passing  math_score  \
# school_name           type
# Bailey High School    District  3124928      0.666801   77.048432
# Cabrera High School   Charter   1081356      0.941335   83.061895
# Figueroa High School  District  1884411      0.659885   76.711767
# Ford High School      District  1763916      0.683096   77.102592
# Griffin High School   Charter    917500      0.933924   83.351499
# Hernandez High School District  3022020      0.667530   77.289752
# Holden High School    Charter    248087      0.925059   83.803279
# Huang High School     District  1910635      0.656839   76.629414
# Johnson High School   District  3094650      0.660576   77.072464
# Pena High School      Charter    585858      0.945946   83.839917
# Rodriguez High School District  2547363      0.663666   76.842711
# Shelton High School   Charter   1056600      0.938671   83.359455
# Thomas High School    Charter   1043130      0.932722   83.418349
# ...

# %%
T1.math_passing=T1.math_passing*100
T1.reading_passing=T1.reading_passing*100
T1.overall_passing=T1.overall_passing*100
T1['budget_student']=T1.budget/T1.number_students
T1
# Out:
#                                  budget  math_passing  math_score  \
# school_name           type
# Bailey High School    District  3124928     66.680064   77.048432
# Cabrera High School   Charter   1081356     94.133477   83.061895
# Figueroa High School  District  1884411     65.988471   76.711767
# Ford High School      District  1763916     68.309602   77.102592
# Griffin High School   Charter    917500     93.392371   83.351499
# Hernandez High School District  3022020     66.752967   77.289752
# Holden High School    Charter    248087     92.505855   83.803279
# Huang High School     District  1910635     65.683922   76.629414
# Johnson High School   District  3094650     66.057551   77.072464
# Pena High School      Charter    585858     94.594595   83.839917
# Rodriguez High School District  2547363     66.366592   76.842711
# Shelton High School   Charter   1056600     93.867121   83.359455
# Thomas High School    Charter   1043130     93.272171   83.418349
# ...

# %% [markdown]
# ## School Summary

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %% [markdown]
# ## Math Scores by Grade

# %% [markdown]
# * Create a table that lists the average Reading Score for students of each grade level (9th, 10th, 11th, 12th) at each school.
#
#   * Create a pandas series for each grade. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %% [markdown]
# ## Reading Score by Grade

# %% [markdown]
# * Perform the same operations as above for reading scores

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Math Score
#   * Average Reading Score
#   * % Passing Math
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type
